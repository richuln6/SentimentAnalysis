# %% [markdown]
# # Step-1 Import All Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step-2 Read The Train Dataset

# %%
df=pd.read_csv('/Users/richu/OneDrive/Desktop/HDS/train.csv')

# %%
df.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y

# %% [markdown]
# # Step-3 PreProcessing the Data

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df['Loan_Status']=le.fit_transform(df['Loan_Status'])
df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)
df['Self_Employed'].fillna('No',inplace=True)
df['Property_Area']=le.fit_transform(df['Property_Area'])
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)
df['Education']=le.fit_transform(df['Education'])
df['Self_Employed']=le.fit_transform(df['Self_Employed'])

# %%
df.head(4)
# Out:
#     Loan_ID Gender Married Dependents  Education  Self_Employed  \
# 0  LP001002   Male      No          0          0              0
# 1  LP001003   Male     Yes          1          0              0
# 2  LP001005   Male     Yes          0          0              1
# 3  LP001006   Male     Yes          0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# 2             1.0              2            1
# 3             1.0              2            1

# %%
fm=df.iloc[:,4:-1]
tv=df['Loan_Status']
fm.head()
# Out:
#    Education  Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0              0             5849                0.0  146.412162
# 1          0              0             4583             1508.0  128.000000
# 2          0              1             3000                0.0   66.000000
# 3          1              0             2583             2358.0  120.000000
# 4          0              0             6000                0.0  141.000000
#
#    Loan_Amount_Term  Credit_History  Property_Area
# 0             360.0             1.0              2
# 1             360.0             1.0              0
# 2             360.0             1.0              2
# 3             360.0             1.0              2
# 4             360.0             1.0              2

# %% [markdown]
# # Step-4 Model Selection And Predicting the Model

# %%
from sklearn.model_selection import train_test_split
fm_train, fm_test,tv_train,tv_test=train_test_split(fm,tv,test_size=0.2)

# %%
print(fm_train.shape)
print(fm_test.shape)
print(tv_train.shape)
print(tv_test.shape)
# Out:
# (491, 8)
# (123, 8)
# (491,)
# (123,)

# %%
plt.scatter(df['ApplicantIncome'],tv)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X=fm_train,y=tv_train)
# Out:
# c:\users\richu\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.intercept_
# Out:
# array([-0.01127724])

# %%
model.coef_
# Out:
# array([[-3.20645994e-01, -2.43939707e-02,  1.22493948e-05,
#         -5.72903924e-05, -1.97594875e-03, -4.07665687e-03,
#          3.03873270e+00,  7.96737817e-02]])

# %%
model.score(X=fm_train,y=tv_train)
# Out:
# 0.8228105906313645

# %%
model.score(X=fm_test,y=tv_test)
# Out:
# 0.7723577235772358

# %%
testdf=pd.read_csv('/Users/richu/OneDrive/Desktop/HDS/dataset/test_lAUu6dG.csv')

# %%
testdf['Gender'].fillna(testdf['Gender'].mode()[0], inplace=True)
testdf['Married'].fillna(testdf['Married'].mode()[0], inplace=True)
testdf['Dependents'].fillna(testdf['Dependents'].mode()[0], inplace=True)
testdf['Loan_Amount_Term'].fillna(testdf['Loan_Amount_Term'].mode()[0], inplace=True)
testdf['Credit_History'].fillna(testdf['Credit_History'].mode()[0], inplace=True)

testdf['LoanAmount'].fillna(testdf['LoanAmount'].mean(), inplace=True)
testdf['Self_Employed'].fillna('No',inplace=True)
testdf['Education']=le.fit_transform(testdf['Education'])

testdf['Self_Employed']=le.fit_transform(testdf['Self_Employed'])
testdf['Property_Area']=le.fit_transform(testdf['Property_Area'])

# %%
fmtest=testdf.iloc[:,4:]
fmtest.head(10)
# Out:
#    Education  Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0              0             5720                  0       110.0
# 1          0              0             3076               1500       126.0
# 2          0              0             5000               1800       208.0
# 3          0              0             2340               2546       100.0
# 4          1              0             3276                  0        78.0
# 5          1              1             2165               3422       152.0
# 6          1              0             2226                  0        59.0
# 7          1              0             3881                  0       147.0
# 8          0              0            13633                  0       280.0
# 9          1              0             2400               2400       123.0
#
#    Loan_Amount_Term  Credit_History  Property_Area
# 0             360.0             1.0              2
# 1             360.0             1.0              2
# 2             360.0             1.0              2
# 3             360.0             1.0              2
# 4             360.0             1.0              2
# 5             360.0             1.0              2
# 6             360.0             1.0              1
# 7             360.0             0.0              0
# 8             240.0             1.0              2
# 9             360.0             1.0              1

# %% [markdown]
# # Step-5 Retrieving the Result

# %%
result=fmtest
a=model.predict(X=fmtest)
result['Loan Status']=a

# %%
result
# Out:
#      Education  Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0              0             5720                  0       110.0
# 1            0              0             3076               1500       126.0
# 2            0              0             5000               1800       208.0
# 3            0              0             2340               2546       100.0
# 4            1              0             3276                  0        78.0
# 5            1              1             2165               3422       152.0
# 6            1              0             2226                  0        59.0
# 7            1              0             3881                  0       147.0
# 8            0              0            13633                  0       280.0
# 9            1              0             2400               2400       123.0
# 10           1              0             3091                  0        90.0
# 11           0              0             2185               1516       162.0
# 12           0              0             4166                  0        40.0
# 13           0              0            12173                  0       166.0
# 14           0              0             4666                  0       124.0
# 15           0              0             5667                  0       131.0
# 16           0              0             4583               2916       200.0
# 17           0              0             3786                333       126.0
# 18           0              0             9226               7916       300.0
# 19           0              0             1300               3470       100.0
# 20           1              0             1888               1620        48.0
# 21           1              0             2083                  0        28.0
# 22           0              0             3909                  0       101.0
# 23           1              0             3765                  0       125.0
# 24           0              0             5400               4380       290.0
# 25           0              0                0              24000       148.0
# 26           0              0             4363               1250       140.0
# 27           0              0             7500               3750       275.0
# 28           0              0             3772                833        57.0
# 29           0              0             2942               2382       125.0
# ..         ...            ...              ...                ...         ...
# 337          0              0             2292               1558       119.0
# 338          0              1             2360               3355        87.0
# 339          0              0             4333               2333       162.0
# 340          0              1             2623               4831       122.0
# 341          0              1             3972               4275       187.0
# 342          1              0             3522                  0        81.0
# 343          0              0             4700                  0        80.0
# 344          0              0             6858                  0       176.0
# 345          0              0             8334                  0       260.0
# 346          0              0             3391               1966       133.0
# 347          1              0             2868                  0        70.0
# 348          1              0             3418               1380       135.0
# 349          0              1             2500                296       137.0
# 350          0              0             8667                  0       254.0
# 351          0              0             2283              15000       106.0
# 352          0              0             5817                910       109.0
# 353          0              0             5119               3769       120.0
# 354          1              0             5316                187       158.0
# 355          0              0             7603               1213       197.0
# 356          0              0             3791               1936        85.0
# 357          0              0             2500                  0        60.0
# 358          1              0             3132                  0        76.0
# 359          0              0             4000               2667       152.0
# 360          0              0             8550               4255        96.0
# 361          0              0             2269               2167        99.0
# 362          1              1             4009               1777       113.0
# 363          0              0             4158                709       115.0
# 364          0              0             3250               1993       126.0
# 365          0              0             5000               2393       158.0
# 366          0              1             9200                  0        98.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan Status
# 0               360.0             1.0              2            1
# 1               360.0             1.0              2            1
# 2               360.0             1.0              2            1
# 3               360.0             1.0              2            1
# 4               360.0             1.0              2            1
# 5               360.0             1.0              2            1
# 6               360.0             1.0              1            1
# 7               360.0             0.0              0            0
# 8               240.0             1.0              2            1
# 9               360.0             1.0              1            1
# 10              360.0             1.0              2            1
# 11              360.0             1.0              1            1
# 12              180.0             1.0              2            1
# 13              360.0             0.0              1            0
# 14              360.0             1.0              1            1
# 15              360.0             1.0              2            1
# 16              360.0             1.0              2            1
# 17              360.0             1.0              1            1
# 18              360.0             1.0              2            1
# 19              180.0             1.0              1            1
# 20              360.0             1.0              2            1
# 21              180.0             1.0              2            1
# 22              360.0             1.0              2            1
# 23              360.0             1.0              2            1
# 24              360.0             1.0              2            1
# 25              360.0             0.0              0            0
# 26              360.0             1.0              2            1
# 27              360.0             1.0              2            1
# 28              360.0             1.0              1            1
# 29              180.0             1.0              2            1
# ..                ...             ...            ...          ...
# 337             360.0             1.0              2            1
# 338             240.0             1.0              0            1
# 339             360.0             0.0              0            0
# 340             180.0             1.0              1            1
# 341             360.0             1.0              0            1
# 342             180.0             1.0              0            1
# 343             360.0             1.0              2            1
# 344             360.0             1.0              0            1
# 345             360.0             1.0              2            1
# 346             360.0             0.0              0            0
# 347             360.0             1.0              2            1
# 348             360.0             1.0              2            1
# 349             300.0             1.0              0            1
# 350             360.0             1.0              0            1
# 351             360.0             1.0              0            1
# 352             360.0             1.0              2            1
# 353             360.0             1.0              0            1
# 354             180.0             0.0              1            0
# 355             360.0             1.0              2            1
# 356             360.0             1.0              2            1
# 357             360.0             1.0              2            1
# 358             360.0             1.0              0            1
# 359             360.0             1.0              1            1
# 360             360.0             1.0              2            1
# 361             360.0             1.0              1            1
# 362             360.0             1.0              2            1
# 363             360.0             1.0              2            1
# 364             360.0             1.0              1            1
# 365             360.0             1.0              0            1
# 366             180.0             1.0              0            1
#
# [367 rows x 9 columns]
